# %%
# %sql

-- bronze_trip_data columns and rows
SELECT COUNT(*) AS total_rows
FROM bronze_trip_data;

SELECT column_name, data_type
FROM information_schema.columns
WHERE table_name = 'bronze_trip_data';

# %%
# %sql

-- bronze_weather_data columns and rows
SELECT COUNT(*) AS total_rows
FROM bronze_weather_data;

SELECT column_name, data_type
FROM information_schema.columns
WHERE table_name = 'bronze_weather_data';
